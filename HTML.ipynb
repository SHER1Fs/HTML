# %% [markdown]
# * **HTML :** HyperText Markup Lanuage , used to build the web
#
#   * has two tags : head and body
#
# * * *
#
# * **!DOCTYPE :**
#
#      * defines the document type and version of HTML , nowadays probably we use HTML5 doctype
#
#      * the word "DOCTYPE" is insensetive your can write it capital or small it does not matter .
#
# * * *
#
# * **meta :**
#
#      * inside the head tag  , self closing tag
#
#      * **meta atributes :**
#
#          * 1 ) **charset :** contain letters encoding type for example (UTF-8)
#
#          * 2 ) **name = "description" content ="" :** the description under the website tilte in web page
#
# * * *
#
# * **style :**
#
#      * inside the head tag , CSS language-specific , contains CSS codes
#
#
# - **script :**
#
#      * inside the head tag , JS language-specific , contains JS scripts
#
# * * *
#
# * **link :**
#
#      * inside the head , Has two atributes :
#
#          * 1 ) **rel :** relation between the HTML file and the webpage
#
#          * 2 ) **href :** where the HTML file is placed
#
# * * *
#
# * **How To Comment in HTML**
#
#      * Ctrl + ? or  Ctrl + ظ
#
#      * <!- - Your Comment -->  " without the the space after the first - "
#
# * * *
# * * *

# %% [markdown]
# # **Headings :**
#
#  *  define headings of different levels from < h1 > (most important) to < h6 > (least important).
#
#  * < h1 > must be used only one time
#
# * * *
# * * *

# %% [markdown]
# # **Paragraphs :**
#
#  * define paragraphs of text
#
#  * < p > Your paragraph of text < /p >
#
#  * every paragraph is a block , and starts in a new line not in the same line
#
#
# * * *
# * * *

# %% [markdown]
# # **Formatting  Elements :**
#
# * **< b >** : to make the element font Bold .
#
# * **< strong >** : same function as b but for important texts .
#
# * **< i >** "italic" and  **< em >** to emphisize text
#
# * **< mark >** : to mark or highlight a text
#
# * **< u >** : to underline a text
#
# * **< small >** : to minimize a text
#
# * **< del >** : for non valid information
#
# * **< ins >** : for new-added or inserted information
#
# * * *
# * * *

# %% [markdown]
# # **Links :**
#
# * we use anchor **< a >** to create links
#
# * For Example :
#
#      * < a href="https://Example.com" > Click Here < /a >
#
#        * **a** stands for anchor which is used to create a basic hyprelink
#
#        * in the **href** atribute we specify the Destination URL
#
#        * Click Here : is the link text, when you click those words we will forwarded to the link you specified in href atribute in the same browser tab
#
#        * if you used **(target="_blank")** atribute the link will be opened in a new tab
#
#        * title atribute : when you point your cursor at the link text this title will appear
#
# * * *
# * * *

# %% [markdown]
# # **Images :**
#
# * we use **< img >** element to embed an image
#
# * < img > element has two main atributes :
#
#     * **1 ) src = "image path" :** the image source link , or an image from the website folder in your PC and if it inside another folder write its path
#
#     * **2 ) alt = "Description of the image" :** allternating text , appear when an error happens if the image source not found
#
# * * *
# * * *

# %% [markdown]
# # **Lists :**
#
#    * **1 ) ul (unordered list) :**
#
#       * used when the order of the items doesn't matter, and they are typically displayed with bullet points.
#
#       * **< ul >** to create it  and the **< li > (list item)** element for each item inside the ul
#
#    * **2 ) ol (ordered list) :**
#
#       * same as ul but , ordered with numbers not bullets
#
#       * < ol reversed > : reverses the ordering
#
#       * < ol start= "specific num" > : ordering strats from this specifc number
#
#       * < li value= "specific num" > : same as the previous
#
#       * < ol type= "A" > : ordering with capital letters .
#
#
#    * **3 ) dl (description list) :**
#
#
#       * creating definition lists, which are often used for glossaries and dictionaries.
#
#       * EX :
#
#          * < dl >
#          * < dt >HTML< /dt >
#          * < dd >HyperText Markup Language< /dd >
#
# * * *
# * * *

# %% [markdown]
# # **Table :**
#
#  * < table >
#
#  * has 3 elements :
#
#       - **1 ) thead :**
#
#            - conatain the first row using < tr > and < td >
#
#       - **2 ) tbody :**
#
#            - contains the table data using < tr > and < td >
#
#       - **3 ) tfoot :**
#
#            * the last row in the table
#
#
#  * < caption > : the title of the table
#
#  * colspan : to merg more than one cell together
#
# * * *
# * * *

# %% [markdown]
#  * < span >  : used to separate an element to deal with it only
#
#  * < br /> : to break a line and start new one
#
#  * < hr > : horizontal line
#
#
# * * *
# * * *

# %% [markdown]
# # **div :**
#
#  * container used to group and structure content
#
# * * *
# * * *

# %% [markdown]
# # **HTML Entities :**
#
#  * https://www.w3schools.com/html/html_entities.asp

# %% [markdown]
# * * *
# * * *
# # **Form :**
#
#
# * < form > consist of :
#
#    * **< input > :** inline self-closing tag
#
#      * input attributes :
#
#          * a ) type : text , password , submit , email , hidden , reset , color , range(value,min,max and step) , number .
#
#            * radio : Creates a radio button for mutually exclusive choices within a group **(only one choise)**
#            * checkbox : Creates a checkbox for binary choices (checked or unchecked) **(multiple choises)**
#
#            * file :  Creates a file input field for file uploads .
#
#            * search :  Creates a search input field
#
#            * URL : Creates an input field for entering a URL only (do not accept regular text)
#
#            * date : Creates an input field for entering a date.
#
#          * b ) required : the input must be filled
#
#          * c ) placeholder : describe the required input same as the label tag , but written inside the input box .
#
#          * d ) value : default value will be displayed before entering any data
#
#          * e ) readonly :  it makes the input control read-only. The user can see the value but cannot modify it.
#
#          * f ) disabled :it disables the input control, making it non-editable and preventing the user from interacting with it.
#
#          * g ) minlength : Specifies the minimum number of characters required in a text input
#
#          * h ) id : to link the input with the label (must be unique)
#
#
#      * **< label > :** describe the required input
#
#        * label attribute :
#
#          * for="id" : to link it with the input
#
#      * **< select > :** used to create a dropdown list , consists of many options Each option is defined by an **< option >** element nested inside the < select > element , those many option can be grouped using **< optgroup >** element
#
#        * < option > attributes :
#
#          * value :  is what gets sent to the server when the form is submitted, while the text content between the opening and closing < option > tags is what is displayed to the user in the dropdown list.
#
#        * < optgroup > attribute :
#
#          * label : the group name
#
#        * select attributes :
#
#          * name : used to identify the field when the form is submitted
#          * id : used to uniquely identify the dropdown list
#          * multiple : to choose more than one option
#
#        * < list > element can do  all < select > functions and can search in it not only choosing
#
#
#      * **< textarea > :** Creates a multi-line text input field
#
#    * form attributes :
#
#      * 1 ) action : Specifies the URL to which the form data should be sent for processing
#
#      * 2 ) name : Provides a name for the form, which can be used to identify the form in scripting .
#
#      * 3 ) method : pecifies the HTTP method to be used when sending form data. The two most common methods are "GET" and "POST" . **post** hide the sent data
#
#      * 4 ) novalidate :disables browser validation of form elements.
#
#      * 5 ) target : Specifies where to display the response received after submitting the form. (_top - _blank - _self - _parent)
#
#      * 6 ) enctype : Specifies how the form data should be encoded before sending it to the server
#
#        * a ) application/x-www-form-urlencoded (default) : It URL-encodes the form data and appends it to the form's action URL as query parameters. Spaces are replaced with the "+" character, and special characters are URL-encoded.
#
#        * b ) multipart/form-data : used when you are uploading files through the form. It is more efficient for binary data like images or documents.
#
#        * c ) text/plain : sends the form data as plain text with no special formatting
#
# * * *
# * * *

# %% [markdown]
# > **< q >**
#
#  * used for quotes
#
# > **< blockquote >**
#
#  * same as q , but this is a block element
#
# > **< button >**
#
#  * when it is pressed it performs a specific function
#
# > **< wbr >**
#
#  * breaks a long url
#
# > **< bdi >**
#
#  * isolate an element from the direction of the page
#
# > **< code >**
#
#  * write a programing code inside it
#
# > **< pre >**
#
#  * any written character in HTML code appears in the browser (space - symboles or anything )
#
# * * *
# * * *

# %% [markdown]
# # **Event Handlers :**
#
#  * attributes that define the behavior of elements in response to various events
#
#  * it is typically a JavaScript code that will be executed when the specified event occurs.
#
#  * EX :
#
#
#     * **1 ) onclick :**
#
#          * Triggered when the user clicks on an element.
#
#     * **2 ) onkeyup :**
#
#          * Triggered when a key is released
#
#     * **3 ) onkeydown :**
#
#          * Triggered when a key is pressed
#
#     * **4 ) onkeypress :**
#
#          * Triggered when a key is pressed or released
#
#     * **5 ) onmouseover :**
#
#          * Triggered when the mouse pointer enters an element.
#
#     * **6 ) onmouseout :**
#
#          * Triggered when the mouse pointer leaves an element.
#
#     * **7 ) onerror :**
#
#          * Triggered when an erro occurs .
#
#     * **8 ) onload :**
#
#          * Triggered when the browser finishes loading the document .
#
#     * **9 ) onfocus :**
#
#          * Triggered when an element gains focus.
#
#
#
# * * *
# * * *
